# %%
import regex
import nltk
nltk.download('punkt')
from datetime import datetime
import nltk
from pymystem3 import Mystem
from gensim.utils import tokenize
from nltk.stem.snowball import SnowballStemmer
from nltk import sent_tokenize
from pymorphy2 import MorphAnalyzer
morph = MorphAnalyzer()
mystem = Mystem()
# Out:
# [nltk_data] Error loading punkt: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1056)>

# %% [markdown]
# # Задание 1.
#
# В re отстутсвуют позитивные квантификаторы. Добавление + к жадному квантификатору делает его позитивным. Он похож
# на жадного, но без бэктрекинга. Основное практическое преимущество позитивных квантификаторов
# состоит в том, что они ускоряют работу регулярного выражения. В частности, позволяют нашему/вашему регулярному выражению
# "сломаться" быстрее. Пример, как работает быстрее:

# %%
text = 'Обработка этой строки должна занять оченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьоченьочень много времени!'
print(datetime.now())
result = regex.match(r'(\w+\s?)*$', text) # отрабатывает за 5-6 тысячных
print(datetime.now(), result)
print(datetime.now())
result = regex.match(r'(\w+\s?)*+$', text) # отрабатывает за 2-3 10тысячных, примерно в 20 раз быстрее
print(datetime.now(), result)
# Out:
# 2019-10-08 20:31:42.156649
# 2019-10-08 20:31:42.170917 None
# 2019-10-08 20:31:42.171812
# 2019-10-08 20:31:42.172532 None

# %% [markdown]
# # Задание 2.

# %%
text = '''
Обстоятельство – второстепенный член предложения, который обозначает признак действия или другого признака. Обстоятельства поясняют сказуемые или другие члены предложения. При синтаксическом разборе предложения обстоятельства подчеркиваются пунктирной линией (тире, точка, тире). Обстоятельства необходимо выделять запятыми в трех случаях. Рассмотрим каждый из них по очереди.
Первый случай
Обстоятельства в предложениях могут быть выражены четырьмя частями речи: 
наречием, например: Дворник встает рано;
деепричастием или деепричастным оборотом, например: Мужики, увидев помещика, сняли шапки;
инфинитивом, например: Все отправились на улицу (зачем?) расчищать снег; 
существительным, например: Я приехал в столицу (зачем?) на экскурсию.
Кроме этого, обстоятельство может быть выражено цельным по смыслу выражением, например: Дождь шел две недели подряд.
Необходимо запомнить, что выделять запятыми нужно обстоятельства, которые выражены деепричастием или деепричастным оборотом. Сравните: Он сидел, листая журнал, и скучал и Он сидел на скамейке. В первом предложении обстоятельство листая журнал выделяется, так как оно выражено деепричастным оборотом, а во втором обстоятельство на скамейке не обособляется, так как оно выражено существительным с предлогом.
Второй и третий случаи
По значению обстоятельства делятся на следующие основные группы: 
обстоятельства места, отвечающие на вопросы ГДЕ? КУДА? ОТКУДА? Например: Мы въехали (куда?) в город; 
обстоятельства времени, отвечающие на вопросы КОГДА? С КАКИХ ПОР? ДО КАКИХ ПОР? КАК ДОЛГО? Например: Мы прождали их около двух часов;
обстоятельства причины, которые отвечают на вопросы ПОЧЕМУ? ОТЧЕГО? ПО КАКОЙ ПРИЧИНЕ? Например: От усталости я не мог говорить; 
обстоятельства цели, которые отвечают на вопросы ЗАЧЕМ? ДЛЯ ЧЕГО? С КАКОЙ ЦЕЛЬЮ? Например: В санатории все приготовлено для лечения отдыхающих;
обстоятельства образа действия и степени, отвечающие на вопросы КАК? КАКИМ ОБРАЗОМ? В КАКОЙ СТЕПЕНИ? Например: Я несколько призадумался или Отец ни на шаг не отпускал меня;
обстоятельства условия, которые отвечают на вопрос ПРИ КАКОМ УСЛОВИИ? Например: При старании можно добиться успеха; 
обстоятельства уступки, которые отвечают на вопрос НЕСМОТРЯ НА ЧТО? Например: На улице, несмотря на мороз, было многолюдно; 
обстоятельства сравнения, отвечающие на вопрос КАК? Например: Голова у нее острижена, как у мальчишки.
В классификации обстоятельств по значению одним из восьми видов являются обстоятельства сравнения: они отвечают на вопрос КАК? и начинается с союзов КАК, СЛОВНО или БУДТО. Например: У нее были длинные волосы, мягкие, как лен. В некоторых учебниках и справочных пособиях обстоятельства сравнения называют также сравнительными оборотами. Необходимо запомнить, что обстоятельства сравнения в предложениях выделяются запятыми.
Еще один вид обстоятельств, который необходимо выделять запятыми, это обстоятельства уступки. Такие обстоятельства отвечают на вопрос НЕСМОТРЯ НА ЧТО? и начинаются с предлога НЕСМОТРЯ НА (или, реже, ВОПРЕКИ). Например: На улицах, несмотря на яркое солнце, горели фонари.
Итак, следует запомнить три случая, когда обстоятельства необходимо выделять запятыми: 
если они выражены деепричастным оборотом, 
если они представляют собой сравнительный оборот, 
если они начинаются с предлога НЕСМОТРЯ НА.
Еще раз рассмотрите примеры. Сверкая быстро в вышине, кружились искры. (Лермонтов) Она вдруг скрылась, как птичка, вспугнутая из кустарника (Лермонтов). Несмотря на непредвиденные трудности, работа закончена в срок.
Это правило имеет несколько важных примечаний: 
От деепричастий следует отличать наречия СТОЯ, СИДЯ, ЛЕЖА, МОЛЧА. НЕХОТЯ, ШУТЯ, НЕ ГЛЯДЯ, ИГРАЯ. Они образовались благодаря переходу слов из разряда деепричастий в наречия. Обстоятельства, выраженные такими словами, не обособляются. Например: Он стоял молча. 
Не выделяются также обстоятельства, выраженные фразеологическими оборотами, например: Они работали засучив рукава или Верчусь целый день как белка в колесе. 
Кроме обстоятельств уступки, которые выделяются всегда, могут факультативно обособляться обстоятельства, выраженные существительными с производными предлогами БЛАГОДАРЯ, СОГЛАСНО, ВОПРЕКИ, ВВИДУ, ВСЛЕДСТВИЕ, например: Благодаря хорошей погоде, мы купались в реке все лето. Обычно такие обстоятельства обособляются, если они распространены и стоят перед сказуемым.
'''
text = text.lower()
words = list(tokenize(text, lowercase=True))
stemmer = SnowballStemmer('russian')
stemmedwords = [(word, stemmer.stem(word)) for word in words]
print(stemmedwords)
# Out:
# [('обстоятельство', 'обстоятельств'), ('второстепенный', 'второстепен'), ('член', 'член'), ('предложения', 'предложен'), ('который', 'котор'), ('обозначает', 'обознача'), ('признак', 'признак'), ('действия', 'действ'), ('или', 'ил'), ('другого', 'друг'), ('признака', 'признак'), ('обстоятельства', 'обстоятельств'), ('поясняют', 'поясня'), ('сказуемые', 'сказуем'), ('или', 'ил'), ('другие', 'друг'), ('члены', 'член'), ('предложения', 'предложен'), ('при', 'при'), ('синтаксическом', 'синтаксическ'), ('разборе', 'разбор'), ('предложения', 'предложен'), ('обстоятельства', 'обстоятельств'), ('подчеркиваются', 'подчеркива'), ('пунктирной', 'пунктирн'), ('линией', 'лин'), ('тире', 'тир'), ('точка', 'точк'), ('тире', 'тир'), ('обстоятельства', 'обстоятельств'), ('необходимо', 'необходим'), ('выделять', 'выделя'), ('запятыми', 'запят'), ('в', 'в'), ('трех', 'трех'), ('случаях', 'случа'), ('рассмотрим', 'рассмотр'), ('каждый', 'кажд'), ('из', 'из'), ('них', 'них'), ('по', 'по'), ('очереди', 'очеред'), ('первый', 'перв'), ('случай', 'случа'), ('обстоятельства', 'обстоятельств'), ('в', 'в'), ('предложениях', 'предложен'), ('могут', 'могут'), ('быть', 'быт'), ('выражены', 'выраж'), ('четырьмя', 'четырьм'), ('частями', 'част'), ('речи', 'реч'), ('наречием', 'нареч'), ('например', 'например'), ('дворник', 'дворник'), ('встает', 'встает'), ('рано', 'ран'), ('деепричастием', 'деепричаст'), ('или', 'ил'), ('деепричастным', 'деепричастн'), ('оборотом', 'оборот'), ('например', 'например'), ('мужики', 'мужик'), ('увидев', 'увид'), ('помещика', 'помещик'), ('сняли', 'снял'), ('шапки', 'шапк'), ('инфинитивом', 'инфинитив'), ('например', 'например'), ('все', 'все'), ('отправились', 'отправ'), ('на', 'на'), ('улицу', 'улиц'), ('зачем', 'зач'), ('расчищать', 'расчища'), ('снег', 'снег'), ('существительным', 'существительн'), ('например', 'например'), ('я', 'я'), ('приехал', 'приеха'), ('в', 'в'), ('столицу', 'столиц'), ('зачем', 'зач'), ('на', 'на'), ('экскурсию', 'экскурс'), ('кроме', 'кром'), ('этого', 'эт'), ('обстоятельство', 'обстоятельств'), ('может', 'может'), ('быть', 'быт'), ('выражено', 'выраж'), ('цельным', 'цельн'), ('по', 'по'), ('смыслу', 'смысл'), ('выражением', 'выражен'), ('например', 'например'), ('дождь', 'дожд'), ('шел', 'шел'), ('две', 'две'), ('недели', 'недел'), ('подряд', 'подряд'), ('необходимо', 'необходим'), ('запомнить', 'запомн'), ('что', 'что'), ('выделять', 'выделя'), ('запятыми', 'запят'), ('нужно', 'нужн'), ('обстоятельства', 'обстоятельств'), ('которые', 'котор'), ('выражены', 'выраж'), ('деепричастием', 'деепричаст'), ('или', 'ил'), ('деепричастным', 'деепричастн'), ('оборотом', 'оборот'), ('сравните', 'сравн'), ('он', 'он'), ('сидел', 'сидел'), ('листая', 'лист'), ('журнал', 'журна'), ('и', 'и'), ('скучал', 'скуча'), ('и', 'и'), ('он', 'он'), ('сидел', 'сидел'), ('на', 'на'), ('скамейке', 'скамейк'), ('в', 'в'), ('первом', 'перв'), ('предложении', 'предложен'), ('обстоятельство', 'обстоятельств'), ('листая', 'лист'), ('журнал', 'журна'), ('выделяется', 'выделя'), ('так', 'так'), ('как', 'как'), ('оно', 'он'), ('выражено', 'выраж'), ('деепричастным', 'деепричастн'), ('оборотом', 'оборот'), ('а', 'а'), ('во', 'во'), ('втором', 'втор'), ('обстоятельство', 'обстоятельств'), ('на', 'на'), ('скамейке', 'скамейк'), ('не', 'не'), ('обособляется', 'обособля'), ('так', 'так'), ('как', 'как'), ('оно', 'он'), ('выражено', 'выраж'), ('существительным', 'существительн'), ('с', 'с'), ('предлогом', 'предлог'), ('второй', 'втор'), ('и', 'и'), ('третий', 'трет'), ('случаи', 'случа'), ('по', 'по'), ('значению', 'значен'), ('обстоятельства', 'обстоятельств'), ('делятся', 'дел'), ('на', 'на'), ('следующие', 'след'), ('основные', 'основн'), ('группы', 'групп'), ('обстоятельства', 'обстоятельств'), ('места', 'мест'), ('отвечающие', 'отвеча'), ('на', 'на'), ('вопросы', 'вопрос'), ('где', 'где'), ('куда', 'куд'), ('откуда', 'откуд'), ('например', 'например'), ('мы', 'мы'), ('въехали', 'въеха'), ('куда', 'куд'), ('в', 'в'), ('город', 'город') ...

# %% [markdown]
# ## Типы ошибок
#
# 1) два разных слова ошибочно свелись к одинаковой основе
#
# В этом тексте почти нет интересных примеров того, как разные слова сводятся к одной основе. Мне встретились только примеры с местоимениями (('они', 'он’), ('оно', 'он’), ('он', 'он’)), местоименными наречиями (('каких', 'как’), ('как', 'как’)) и путаница со словами «не» и «нее» ( ('не', 'не’), ('нее', 'не’)). Также мне попалась путаница с глаголами и глагольными формами: ('следующие', 'след’) и ('следует', ‘след’). При этом остается открытым вопрос, считать ли в рамках этого задания причастие «следующий» формой глагола «следовать» или же это отдельное слово.
#
# 2) две словоформы одного слова после стемминга отличаются друг от друга
#
# Мне встретилась такая путаница только с одним глаголом: ('стоял', 'стоя’) и ('стоят', 'сто’).
#
# 3) слово не изменилось после стемминга (слово должно быть русским и длиннее 4 символов)
#
# Вот что мне попалось: ('например', 'например'), ('дворник', 'дворник'), ('встает', 'встает’), ('сидел', ‘сидел’), ('имеет', 'имеет’), ('могут', 'могут')

# %% [markdown]
# ## Задание 3.
#
# 1) Производные предлоги
#
# В списке NLTK вообще не представлена эта группа слов, и на самом деле понятно, почему их там нет: все дело в том,
# что большинство этих предлогов можно спутать с другими частями речи. И тем не менее предлоги "несмотря на" и "невзирая на", например, не спутаешь с
# деепричастиями "смотря" и "взирая" благодаря приставке "не", поэтому их можно смело добавить (точнее, первую часть "несмотря" и "невзирая"). Как и предлог "вопреки",
# для которого нет омонимии в виде наречия или любой другой части речи.
#
# 2) Числительные
#
# В списке есть только "один", "два" и "три", тогда как можно добавить и остальные числительные до "десяти": "четыре", "пять", "шесть"
# и т.д., т.к. они особой роли при анализе текста не играют.
#
# 3) Наречия
#
# В списке есть слова "много" и "больше", а противоположных по значению "мало" и "меньше" почему-то нет. Они играют одинаковую
# роль в тексте, показывая лишь перевес в одну или другую сторону (что-то больше или меньше, чего-то много или мало), поэтому их
# можно добавить сюда.
#
# # Задание 4.

# %%
#mystem
text2 = '''
Эксперты нашли экстремизм в призывах Егора Жукова «бороться, чтобы Россия стала свободной»
​«Новая газета» опубликовала сокращенный вариант заключения экспертов Александра Коршикова и Анны Осокиной, которые анализировали видео из блога студента Высшей школы экономики Егора Жукова, обвиняемого в призывах к экстремизму в интернете (часть 2 статьи 280 УК).
Эксперты нашли экстремизм в четырех видео на YouTube-канале Жукова. По их мнению, в видео «отчетливо прослеживается мотив политической ненависти или вражды к действующей власти».
В заключении говорится, что Жуков приписывает действующей власти «враждебные действия», называет ее врагами, источником зла и вреда. Кроме того, студент призывает с этой властью бороться.
«Автор описывает катастрофическое положение населения в России, как следствие целенаправленной политики действующей власти <...>. Основным идеалом, которого следует достичь, является "смена власти в России" для того, чтобы "Россия стала свободной"», — цитирует издание экспертов.
В одном из видео, в котором Жуков размышлял об итогах митинга 7 октября 2017 года, эксперты увидели призыв бороться любым способом, «что включает в себя и действия насильственного характера, в частности, насильственный захват власти, вооруженный мятеж».
Егор Жуков — фигурант «московского дела». Сначала его обвиняли в участии в массовых беспорядках (часть 2 статьи 212 УК). В суде говорили, что среди материалов есть видео, где Жуков показывает кому-то направо на акции 27 июля. Из-за этого студента 2 августа отправили в СИЗО.
Однако через месяц дело о массовых беспорядках против Жукова закрыли, ему предъявили новое обвинение в призывах к экстремизму. По ходатайстве следствие суд перевел студента под домашний арест.
'''

words2_analized = mystem.lemmatize(text2)
print(words2_analized)
# Out:
# ['\n', 'эксперт', ' ', 'находить', ' ', 'экстремизм', ' ', 'в', ' ', 'призыв', ' ', 'егор', ' ', 'жуков', ' «', 'бороться', ', ', 'чтобы', ' ', 'россия', ' ', 'становиться', ' ', 'свободный', '»\n', '\u200b«', 'новый', ' ', 'газета', '» ', 'опубликовывать', ' ', 'сокращать', ' ', 'вариант', ' ', 'заключение', ' ', 'эксперт', ' ', 'александр', ' ', 'коршиков', ' ', 'и', ' ', 'анна', ' ', 'осокина', ', ', 'который', ' ', 'анализировать', ' ', 'видео', ' ', 'из', ' ', 'блог', ' ', 'студент', ' ', 'высокий', ' ', 'школа', ' ', 'экономика', ' ', 'егор', ' ', 'жуков', ', ', 'обвиняемый', ' ', 'в', ' ', 'призыв', ' ', 'к', ' ', 'экстремизм', ' ', 'в', ' ', 'интернет', ' (', 'часть', ' ', '2', ' ', 'статья', ' ', '280', ' ', 'ук', ')', '.', '\n', 'эксперт', ' ', 'находить', ' ', 'экстремизм', ' ', 'в', ' ', 'четыре', ' ', 'видео', ' ', 'на', ' ', 'YouTube', '-', 'канал', ' ', 'жуков', '. ', 'по', ' ', 'их', ' ', 'мнение', ', ', 'в', ' ', 'видео', ' «', 'отчетливо', ' ', 'прослеживаться', ' ', 'мотив', ' ', 'политический', ' ', 'ненависть', ' ', 'или', ' ', 'вражда', ' ', 'к', ' ', 'действующий', ' ', 'власть', '»', '.', '\n', 'в', ' ', 'заключение', ' ', 'говориться', ', ', 'что', ' ', 'жуков', ' ', 'приписывать', ' ', 'действующий', ' ', 'власть', ' «', 'враждебный', ' ', 'действие', '», ', 'называть', ' ', 'ее', ' ', 'враг', ', ', 'источник', ' ', 'зло', ' ', 'и', ' ', 'вред', '. ', 'кроме', ' ', 'то', ', ', 'студент', ' ', 'призывать', ' ', 'с', ' ', 'этот', ' ', 'власть', ' ', 'бороться', '.', '\n', '«', 'автор', ' ', 'описывать', ' ', 'катастрофический', ' ', 'положение', ' ', 'население', ' ', 'в', ' ', 'россия', ', ', 'как', ' ', 'следствие', ' ', 'целенаправленный', ' ', 'политика', ' ', 'действовать', ' ', 'власть', ' <', '...>. ', 'основной', ' ', 'идеал', ', ', 'который', ' ', 'следовать', ' ', 'достигать', ', ', 'являться', ' "', 'смена', ' ', 'власть', ' ', 'в', ' ', 'россия', '" ', 'для', ' ', 'то', ', ', 'чтобы', ' "', 'россия', ' ', 'становиться', ' ', 'свободный', '"», — ', 'цитировать', ' ', 'издание', ' ', 'эксперт', '.', '\n', 'в', ' ', 'один', ' ', 'из', ' ', 'видео', ', ', 'в', ' ', 'который', ' ', 'жуков', ' ', 'размышлять', ' ', 'об', ' ', 'итог', ' ', 'митинг', ' ', '7', ' ', 'октябрь', ' ', '2017', ' ', 'год', ', ', 'эксперт', ' ', 'увидеть', ' ', 'призыв', ' ', 'бороться', ' ', 'любой', ' ', 'способ', ', «', 'что', ' ', 'включать', ' ', 'в', ' ', 'себя', ' ', 'и', ' ', 'действие', ' ', 'насильственный', ' ', 'характер', ', ', 'в', ' ', 'частность', ', ', 'насильственный', ' ', 'захват', ' ', 'власть', ', ', 'вооруженный', ' ', 'мятеж', '»', '.', '\n', 'егор', ' ', 'жуков', ' — ', 'фигурант', ' «', 'московский', ' ', 'дело', '»', '. ', 'сначала', ' ', 'он', ' ', 'обвинять', ' ', 'в', ' ', 'участие', ' ', 'в', ' ', 'массовый', ' ', 'беспорядок', ' (', 'часть', ' ', '2', ' ', 'статья', ' ', '212', ' ', 'ук', ')', '. ', 'в', ' ', 'суд', ' ', 'говорить', ', ', 'что', ' ', 'среди', ' ', 'материал', ' ', 'быть', ' ', 'видео', ', ', 'где', ' ', 'жуков', ' ', 'показывать', ' ', 'кто-то', ' ', 'направо', ' ', 'на', ' ', 'акция', ' ', '27', ' ', 'июль', '. ', 'из-за', ' ', 'этот', ' ', 'студент', ' ', '2', ' ', 'август', ' ', 'отправлять', ' ', 'в', ' ', 'сизо', '.', '\n', 'однако', ' ', 'через', ' ', 'месяц', ' ', 'дело', ' ', 'о', ' ', 'массовый', ' ', 'беспорядок', ' ', 'против', ' ', 'жуков', ' ', 'закрывать', ', ', 'он', ' ', 'предъявлять', ' ', 'новый', ' ', 'обвинение', ' ', 'в', ' ', 'призыв', ' ', 'к', ' ', 'экстремизм', '. ', 'по', ' ', 'ходатайство', ' ', 'следствие', ' ', 'суд', ' ', 'переводить', ' ', 'студент', ' ', 'под', ' ', 'домашний', ' ', 'арест', '.', '\n']

# %%
#pymorphy
text2 = '''
Эксперты нашли экстремизм в призывах Егора Жукова «бороться, чтобы Россия стала свободной»
​«Новая газета» опубликовала сокращенный вариант заключения экспертов Александра Коршикова и Анны Осокиной, которые анализировали видео из блога студента Высшей школы экономики Егора Жукова, обвиняемого в призывах к экстремизму в интернете (часть 2 статьи 280 УК).
Эксперты нашли экстремизм в четырех видео на YouTube-канале Жукова. По их мнению, в видео «отчетливо прослеживается мотив политической ненависти или вражды к действующей власти».
В заключении говорится, что Жуков приписывает действующей власти «враждебные действия», называет ее врагами, источником зла и вреда. Кроме того, студент призывает с этой властью бороться.
«Автор описывает катастрофическое положение населения в России, как следствие целенаправленной политики действующей власти <...>. Основным идеалом, которого следует достичь, является "смена власти в России" для того, чтобы "Россия стала свободной"», — цитирует издание экспертов.
В одном из видео, в котором Жуков размышлял об итогах митинга 7 октября 2017 года, эксперты увидели призыв бороться любым способом, «что включает в себя и действия насильственного характера, в частности, насильственный захват власти, вооруженный мятеж».
Егор Жуков — фигурант «московского дела». Сначала его обвиняли в участии в массовых беспорядках (часть 2 статьи 212 УК). В суде говорили, что среди материалов есть видео, где Жуков показывает кому-то направо на акции 27 июля. Из-за этого студента 2 августа отправили в СИЗО.
Однако через месяц дело о массовых беспорядках против Жукова закрыли, ему предъявили новое обвинение в призывах к экстремизму. По ходатайстве следствие суд перевел студента под домашний арест.
'''
text2 = text2.lower()
sentences2 = sent_tokenize(text2, 'russian')
token2 = wordpunct_tokenize(sentences2)
words_analized2 = [morph.parse(token2) for token2 in wordpunct_tokenize(text2)]
print(words_analized2)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-31-ba0f113430aa> in <module>
#      12 '''
#      13 text2 = text2.lower()
# ---> 14 sentences2 = sent_tokenize(text2, 'russian')
#      15 token2 = wordpunct_tokenize(sentences2)
#      16 words_analized2 = [morph.parse(token2) for token2 in wordpunct_tokenize(text2)]
#
# ~/PycharmProjects/compling_homeworks/venv/lib/python3.7/site-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#     103     :param language: the model name in the Punkt corpus
#     104     """
# --> 105     tokenizer = load('tokenizers/punkt/{0}.pickle'.format(language))
#     106     return tokenizer.tokenize(text)
#     107
#
# ~/PycharmProjects/compling_homeworks/venv/lib/python3.7/site-packages/nltk/data.py in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     866
#     867     # Load the resource.
# --> 868     opened_resource = _open(resource_url)
#     869
#     870     if format == 'raw':
#
# ~/PycharmProjects/compling_homeworks/venv/lib/python3.7/site-packages/nltk/data.py in _open(resource_url)
#     991
#     992     if protocol is None or protocol.lower() == 'nltk':
# --> 993         return find(path_, path + ['']).open()
#     994     elif protocol.lower() == 'file':
#     995         # urllib might not use mode='rb', so handle this one ourselves:
#
# ~/PycharmProjects/compling_homeworks/venv/lib/python3.7/site-packages/nltk/data.py in find(resource_name, paths)
#     699     sep = '*' * 70
#     700     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 701     raise LookupError(resource_not_found)
#     702
#     703
#
# LookupError:
# **********************************************************************
#   Resource punkt not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt/PY3/russian.pickle
#
#   Searched in:
#     - '/Users/vladislavasan/nltk_data'
#     - '/Users/vladislavasan/PycharmProjects/compling_homeworks/venv/nltk_data'
#     - '/Users/vladislavasan/PycharmProjects/compling_homeworks/venv/share/nltk_data'
#     - '/Users/vladislavasan/PycharmProjects/compling_homeworks/venv/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
#     - ''
# **********************************************************************

# %% [markdown]
# 1) Что лучше разбивает на предложения (mystem или sent_tokenize)?
# 2) Что лучше токенизирует (mystem или ваша регулярка)? Если mystem, то можно ли улучшить регулярное выражение так, чтобы качество было выше?
# 3) Что лучше для лемматизации mystem или pymorphy?
